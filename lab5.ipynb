# %%
#1d
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==5*x+3*y+1
ec2=diff(y,t)==-6*x-4*y+exp(-t)
sist=[ec1,ec2]
desolve_system(sist,[x,y])
# Out:
# [x(t) == 1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) - t*e^(-t) - 1/3*(3*x(0) + 3*y(0) - 2)*e^(-t) - 2,
#  y(t) == -1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) + 2*t*e^(-t) + 1/3*(6*x(0) + 6*y(0) - 5)*e^(-t) + 3]

# %%
#1a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==x+4*y
ec2=diff(y,t)==-x+y
sist=[ec1,ec2]
desolve_system(sist,[x,y])
# Out:
# [x(t) == (cos(2*t)*x(0) + 2*sin(2*t)*y(0))*e^t,
#  y(t) == -1/2*(sin(2*t)*x(0) - 2*cos(2*t)*y(0))*e^t]

# %%
#1b
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==2*x-y
ec2=diff(y,t)==x+2*y
sist=[ec1,ec2]
desolve_system(sist,[x,y])
# Out:
# [x(t) == (cos(t)*x(0) - sin(t)*y(0))*e^(2*t),
#  y(t) == (sin(t)*x(0) + cos(t)*y(0))*e^(2*t)]

# %%
#1c
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
ec1=diff(x,t)==x-y+z
ec2=diff(y,t)==x+y-z
ec3=diff(z,t)==-y+2*z
sist=[ec1,ec2,ec3]
desolve_system(sist,[x,y,z])
# Out:
# [x(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (2*x(0) + y(0) - 2*z(0))*e^t,
#  y(t) == t*e^t*x(0) - t*e^t*z(0) + e^t*y(0),
#  z(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (x(0) + y(0) - z(0))*e^t]

# %%
#2a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==x+4*y
ec2=diff(y,t)==x+y
sist=[ec1,ec2]
sol=desolve_system(sist,[x,y],[0,1,2])
sol
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
x(t)=sol[0].rhs()
y(t)=sol[1].rhs()
x(t)
# Out:
# 5/2*e^(3*t) - 3/2*e^(-t)

# %%
y(t)
# Out:
# 5/4*e^(3*t) + 3/4*e^(-t)

# %%
g1=plot(x(t),t,-4,4,color='red',ymin=-20,ymax=20)
g2=plot(y(t),t,-4,4,color='blue',ymin=-20,ymax=20)
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#2b
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==x-y+t
ec2=diff(y,t)==-2*x+4*y+cos(t)
sist=[ec1,ec2]
sol=desolve_system(sist,[x,y],[0,0,1])
sol
# Out:
# [x(t) == -1/221*(274*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1003*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 9/2,
#  y(t) == -1/442*(181*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1649*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 5/2]

# %%
x(t)=sol[0].rhs()
y(t)=sol[1].rhs()
x(t)
# Out:
# -1/221*(274*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1003*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 9/2

# %%
y(t)
# Out:
# -1/442*(181*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1649*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 5/2

# %%
g1=plot(x(t),t,-4,4,color='red',ymin=-20,ymax=20)
g2=plot(y(t),t,-4,4,color='blue',ymin=-20,ymax=20)
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#2c
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==x+2*y+t+exp(-t)
ec2=diff(y,t)==-2*x+y+1
sist=[ec1,ec2]
sol=desolve_system(sist,[x,y],[0,0,1])
sol
# Out:
# [x(t) == -1/100*(27*cos(2*t) - 161*sin(2*t))*e^t - 1/5*t - 1/4*e^(-t) + 13/25,
#  y(t) == 1/100*(161*cos(2*t) + 27*sin(2*t))*e^t - 2/5*t - 1/4*e^(-t) - 9/25]

# %%
x(t)=sol[0].rhs()
y(t)=sol[1].rhs()
x(t)
# Out:
# -1/100*(27*cos(2*t) - 161*sin(2*t))*e^t - 1/5*t - 1/4*e^(-t) + 13/25

# %%
y(t)
# Out:
# 1/100*(161*cos(2*t) + 27*sin(2*t))*e^t - 2/5*t - 1/4*e^(-t) - 9/25

# %%
g1=plot(x(t),t,-4,4,color='red',ymin=-50,ymax=50)
g2=plot(y(t),t,-4,4,color='blue',ymin=-50,ymax=50)
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#3a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==y
ec2=diff(y,t)==-x-2*y
sist=[ec1,ec2]
sol=desolve_system(sist,[x,y])
sol
# Out:
# [x(t) == t*e^(-t)*x(0) - 3*t*e^(-t) + e^(-t)*x(0),
#  y(t) == -t*e^(-t)*x(0) + 3*t*e^(-t) - 3*e^(-t)]

# %%
#3b
x(t)=sol[0].rhs()
y(t)=sol[1].rhs()
x(t)
# Out:
# t*e^(-t)*x(0) - 3*t*e^(-t) + e^(-t)*x(0)

# %%
y(t)
# Out:
# -t*e^(-t)*x(0) + 3*t*e^(-t) - 3*e^(-t)

# %%
limit(x(t),t=infinity)
# Out:
# 0

# %%
limit(y(t),t=infinity)
# Out:
# 0

# %%
#c
c1=[0,3,0]
c2=[0,0,3]
c3=[0,3,0]
c4=[0,0,-3]
sol1=desolve_system(sist,[x,y],c1)
sol2=desolve_system(sist,[x,y],c2)
sol3=desolve_system(sist,[x,y],c3)
sol4=desolve_system(sist,[x,y],c4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/interfaces/interface.py in __init__(self, parent, value, is_name, name)
#     718             try:
# --> 719                 self._name = parent._create(value, name=name)
#     720             except (TypeError, RuntimeError, ValueError) as x:
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/interfaces/maxima_lib.py in _create(self, value, name)
#     604             else:
# --> 605                 self.set(name, value)
#     606         except RuntimeError as error:
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/interfaces/maxima_lib.py in set(self, var, value)
#     513         cmd = '%s : %s$'%(var, value.rstrip(';'))
# --> 514         self.eval(cmd)
#     515
#
# ...

# %%
x1(t)=sol1[0].rhs()
y1(t)=sol1[1].rhs()
x2(t)=sol2[0].rhs()
y2(t)=sol2[1].rhs()
x3(t)=sol3[0].rhs()
y3(t)=sol3[1].rhs()
x4(t)=sol4[0].rhs()
y4(t)=sol4[1].rhs()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/all_cmdline.py in <module>()
# ----> 1 __tmp__=var("t"); x1 = symbolic_expression(sol1[Integer(0)].rhs()).function(t)
#       2 __tmp__=var("t"); y1 = symbolic_expression(sol1[Integer(1)].rhs()).function(t)
#       3 __tmp__=var("t"); x2 = symbolic_expression(sol2[Integer(0)].rhs()).function(t)
#       4 __tmp__=var("t"); y2 = symbolic_expression(sol2[Integer(1)].rhs()).function(t)
#       5 __tmp__=var("t"); x3 = symbolic_expression(sol3[Integer(0)].rhs()).function(t)
#
# NameError: name 'sol1' is not defined

# %%
f1(u,v)=v
f2(u,v)=-u-2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g=plot_vector_field([f1(u,v)/n,f2(u,v)/n],[u,-5,5],[v,-5,5],color='red',aspect_ratio=1)
g1=parametric_plot((x1(t),y1(t)),(t,-10,10),color='blue')
g2=parametric_plot((x2(t),y2(t)),(t,-10,10),color='green')
g3=parametric_plot((x3(t),y3(t)),(t,-10,10),color='purple')
g4=parametric_plot((x4(t),y4(t)),(t,-10,10),color='black')
gg=g+g1+g2+g3+g4
gg.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
#4a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==2*x+y
ec2=diff(y,t)==x+2*y
sist=[ec1,ec2]
sol=desolve_system(sist,[x,y])
sol
# Out:
# [x(t) == 1/2*(x(0) - 3)*e^(3*t) + 1/2*(x(0) + 3)*e^t,
#  y(t) == 1/2*(x(0) - 3)*e^(3*t) - 1/2*(x(0) + 3)*e^t]

# %%
f1(u,v)=2*u+v
f2(u,v)=u+2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g=plot_vector_field([f1(u,v)/n,f2(u,v)/n],[u,-5,5],[v,-5,5],color='red',aspect_ratio=1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#4b
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==y
ec2=diff(y,t)==-x
sist=[ec1,ec2]
sol=desolve_system(sist,[x,y])
sol
# Out:
# [x(t) == cos(t)*x(0) - 3*sin(t), y(t) == -sin(t)*x(0) - 3*cos(t)]

# %%
f1(u,v)=v
f2(u,v)=-u
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g=plot_vector_field([f1(u,v)/n,f2(u,v)/n],[u,-5,5],[v,-5,5],color='red',aspect_ratio=1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#4c
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==-x-y
ec2=diff(y,t)==x-y
sist=[ec1,ec2]
sol=desolve_system(sist,[x,y])
sol
# Out:
# [x(t) == (cos(t)*x(0) + 3*sin(t))*e^(-t),
#  y(t) == (sin(t)*x(0) - 3*cos(t))*e^(-t)]

# %%
f1(u,v)=-u-v
f2(u,v)=u-v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g=plot_vector_field([f1(u,v)/n,f2(u,v)/n],[u,-5,5],[v,-5,5],color='red',aspect_ratio=1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#4d
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
ec1=diff(x,t)==-2*x
ec2=diff(y,t)==-4*x-2*y
sist=[ec1,ec2]
sol=desolve_system(sist,[x,y])
sol
# Out:
# [x(t) == e^(-2*t)*x(0), y(t) == -4*t*e^(-2*t)*x(0) - 3*e^(-2*t)]

# %%
f1(u,v)=-2*u
f2(u,v)=-4*u-2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g=plot_vector_field([f1(u,v)/n,f2(u,v)/n],[u,-5,5],[v,-5,5],color='red',aspect_ratio=1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive
