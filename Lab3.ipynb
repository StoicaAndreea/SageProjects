# %%
#1b
reset()
x=var('x')
y=function('y')(x)
ec=diff(y,x,2)-y==exp(2*x)
f(x,_K1,_K2)=desolve(ec,y)
f(x,_K1,_K2)
# Out:
# _K2*e^(-x) + _K1*e^x + 1/3*e^(2*x)

# %%
plot(f(x,0,1),x,-10,10,ymin=-20,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#1a
reset()
x=var('x')
y=function('y')(x)
ec=diff(y,x,2)+y==sin(x)+cos(x)
f(x,_K1,_K2)=desolve(ec,y)
f(x,_K1,_K2)
# Out:
# _K2*cos(x) - 1/2*(x - 1)*cos(x) + _K1*sin(x) + 1/2*x*sin(x)

# %%
plot(f(x,0,1),x,-50,50,ymin=-20,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#1c
reset()
x=var('x')
y=function('y')(x)
ec=diff(y,x,2)+4*y==cos(2*x)
f(x,_K1,_K2)=desolve(ec,y)
f(x,_K1,_K2)
# Out:
# _K2*cos(2*x) + _K1*sin(2*x) + 1/4*x*sin(2*x) + 1/8*cos(2*x)

# %%
plot(f(x,0,1),x,-100,100,ymin=-20,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#1d
reset()
x=var('x')
y=function('y')(x)
ec=diff(y,x,2)-diff(y,x)==1/(1+exp(x))
f(x,_K1,_K2)=desolve(ec,y)
f(x,_K1,_K2)
# Out:
# _K1*e^x + e^x*log((e^x + 1)*e^(-x)) + _K2 - x + log(e^x + 1)

# %%
plot(f(x,0,1),x,-10,10,ymin=-20,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#2 exemplu
reset()
x=var('x')
y=function('y')(x)
ec=diff(y,x,2)+y==sin(x)+cos(x)
f(x)=desolve(ec,y,ics=[0,5,8])
f(x)
# Out:
# -1/2*(x - 1)*cos(x) + 1/2*x*sin(x) + 9/2*cos(x) + 17/2*sin(x)

# %%
#2a
reset()
x=var('x')
y=function('y')(x)
ec=diff(y,x,2)-5*diff(y,x)+4*y==0
f(x)=desolve(ec,y,ics=[0,5,8])
f(x)
# Out:
# e^(4*x) + 4*e^x

# %%
plot(f(x),x,-10,10,ymin=-20,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#2b
reset()
x=var('x')
y=function('y')(x)
ec=diff(y,x,2)-4*diff(y,x)+5*y==2*x^2*exp(x)
f(x)=desolve(ec,y,ics=[0,2,3])
f(x)
# Out:
# (cos(x) - 2*sin(x))*e^(2*x) + (x^2 + 2*x + 1)*e^x

# %%
plot(f(x),x,-50,50,ymin=-100,ymax=100)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#2c
reset()
x=var('x')
y=function('y')(x)
ec=diff(y,x,2)+4*y==4*(sin(2*x)+cos(2*x))
f(x)=desolve(ec,y,ics=[pi,2*pi,2*pi])
f(x)
# Out:
# 1/2*(6*pi - 1)*cos(2*x) - 1/2*(2*x - 1)*cos(2*x) + x*sin(2*x) + 1/2*sin(2*x)

# %%
plot(f(x),x,-50,50,ymin=-100,ymax=100)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#3 exemplu
reset()
x,a=var('x,a')
y=function('y')(x)
ec=diff(y,x,2)-diff(y,x)-2*y==0
f(x,a)=desolve(ec,y,ivar=x,ics=[0,a,2])
limit(f(x,-2),x=infinity)
#sage nu stie sa gaseasca pe a, trebuie sa gasim noi solutia si sa verificam...
# Out:
# 0
