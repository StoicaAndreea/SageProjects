# %%
12
# Out:
# 12

# %%
#1a
12+4-5
# Out:
# 11

# %%
#1b
12 + 4 - 5
# Out:
# 11

# %%
#1c
2^10
# Out:
# 1024

# %%
#1d
sin(pi/2)
# Out:
# 1

# %%
#1
sin(0.1)
# Out:
# 0.0998334166468282

# %%
#1
14+2*(5-3)
# Out:
# 18

# %%
eq1=x^4-(3/2)*x^3-x+3/2==0 
solve(eq1,x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
#exercitiul 2

# %%
#a

# %%
eq1=x^4-(3/2)*x^3-x+3/2==0 
solve(eq1,x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
#b

# %%
eq2=sqrt(x^2+2*x)==3-x
solve(eq2,x)
# Out:
# [x == -sqrt(x^2 + 2*x) + 3]

# %%
x=var('x')
eq2= x+sqrt(x^2+2*x)==3
solve(eq2,x)
# Out:
# [x == -sqrt(x^2 + 2*x) + 3]

# %%
#exercitiul3

# %%
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
limit((x^3+3*(x^2)-5)/(2*x^3-7*x), x=infinity)
# Out:
# 1/2

# %%
limit((cos(x)+1)/(x-pi),x=pi)
# Out:
# 0

# %%
y(x)=3*(x^3)+2*(x^2)-5
diff(y(x),x)
# Out:
# 9*x^2 + 4*x

# %%
z(x)=sqrt(1+(x^4))
diff(z(x),x)
# Out:
# 2*x^3/sqrt(x^4 + 1)

# %%
integrate(3*(x^3)+2*(x^2)-5,x,0,1)
# Out:
# -43/12

# %%
integrate(1/(x^2),x,1,infinity)
# Out:
# 1

# %%
integrate(exp(-x^2),x,-infinity,infinity)
# Out:
# sqrt(pi)

# %%
#ex6

# %%
#a
f(x)=exp(-x)-1
plot(f(x),-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#b1
r=var('r')
r=0.5
f(x)=200*exp(r*x)/(2*(exp(r*x)-1)+100)
plot(f(x),0,50)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#b2
r=var('r')
r=-0.5
f(x)=200*exp(r*x)/(2*(exp(r*x)-1)+100)
plot(f(x),0,50)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#7 a
t=var('t')
x(t)=(1-cos(t))*cos(t)
y(t)=(1-cos(t))*sin(t)
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#7 b
t=var('t')
x(t)=sin(3*t)*cos(t)
y(t)=sin(3*t)*sin(t)
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#7c
t=var('t')
x(t)=t-sin(t)
y(t)=1-cos(t)
parametric_plot((x(t),y(t)),(t,0,6*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#7d
t=var('t')
x(t)=cos(t)+cos(7*t)/2+sin(17*t)/3
y(t)=sin(t)+sin(7*t)/2+cos(17*t)/3
parametric_plot((x(t),y(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#8a
t,s=var('t,s')
f(t,s)=1-(s*cos(4*t)*cos(t))/sqrt(1-s^2*cos(4*t)^2*sin(t)^2)
x(t,s)=f(t-pi/2,s)
y(t,s)=f(t,s)
s=0.5
parametric_plot((x(t,s),y(t,s)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#8b
t,s=var('t,s')
f(t,s)=1-(s*cos(4*t)*cos(t))/sqrt(1-s^2*cos(4*t)^2*sin(t)^2)
x(t,s)=f(t-pi/2,s)
y(t,s)=f(t,s)
s=0.5
g1=parametric_plot((x(t,0.1),y(t,0.1)),(t,0,2*pi))
g2=parametric_plot((x(t,0.2),y(t,0.2)),(t,0,2*pi))
g3=parametric_plot((x(t,0.3),y(t,0.3)),(t,0,2*pi))
g4=parametric_plot((x(t,0.4),y(t,0.4)),(t,0,2*pi))
g5=parametric_plot((x(t,0.5),y(t,0.5)),(t,0,2*pi))
g6=parametric_plot((x(t,0.6),y(t,0.6)),(t,0,2*pi))
g7=parametric_plot((x(t,0.7),y(t,0.7)),(t,0,2*pi))
g8=parametric_plot((x(t,0.8),y(t,0.8)),(t,0,2*pi))
g9=parametric_plot((x(t,0.9),y(t,0.9)),(t,0,2*pi))
g10=parametric_plot((x(t,1),y(t,1)),(t,0,2*pi))
show(g1+g2+g3+g4+g5+g6+g7+g8+g9+g10)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
#9a
x,y=var('x,y')
f(x,y)=x^2+y^2-2*x-4*y
implicit_plot(f(x,y)==0,(x,-5,5),(y,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#9b
x,y=var('x,y')
f(x,y)=x^2-2*x*y-y^2
implicit_plot(f(x,y)==1,(x,-10,10),(y,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#9c
x,y=var('x,y')
f(x,y)=6*x^2-4*x*y+9*y^2-24*x-32*y-6
implicit_plot(f(x,y)==0,(x,-10,10),(y,-5,7))
# Out:
# Graphics object consisting of 1 graphics primitive
